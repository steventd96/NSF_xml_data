# %%
import pandas as pd
pd.set_option('display.max_columns',5000)

# %%
df16 = pd.read_csv('2019_data.csv')
df16.head()
# Out:
#    Unnamed: 0                                         AwardTitle  \
# 0           0  Social, Behavioral, and Academic Linkages thro...
# 1           0  Student Travel to the Cornell, Maryland, Max P...
# 2           0  SBIR Phase I:  Droplet Transport Technology fo...
# 3           0  2019 Coastal Ocean Dynamics Gordon Research Co...
# 4           0  The 10th USA-China Joint Chemical Engineering ...
#
#   AwardEffectiveDate AwardExpirationDate  AwardTotalIntnAmount  AwardAmount  \
# 0         02/01/2018          06/30/2020              216805.0       216805
# 1         04/15/2019          03/31/2020               49979.0        49979
# 2         06/01/2019          05/31/2020              225000.0       225000
# 3         04/15/2019          09/30/2019               29850.0        29850
# 4         11/01/2019          10/31/2020               30000.0        30000
#
#   AwardInstrument           Value Organization     Code Directorate  \
# ...

# %%
col_name_mapping = {
    'Code': 'Organization Code',
    'Value': 'AwardInstrument Value',
    'Code': 'Directorate Code',
    'LongName': 'Organization Directorate LongName',
    'LongName_1': 'Organization Division LongName',
    'SignBlockName':'ProgramOfficer SignBlockName',
    'FirstName':'Investigator FirstName',
    'LastName':'Investigator LastName',
    'EmailAddress':'Investigator EmailAddress',
    'StartDate':'Investigator StartDate',
    'RoleCode':'Investigator RoleCode',
    'EndDate':'Investigator EndDate',
    'FirstName_1':'Investigator FirstName_1',
    'LastName_1':'Investigator LastName_1',
    'EmailAddress_1':'Investigator EmailAddress_1',
    'StartDate_1':'Investigator StartDate_1',
    'RoleCode_1':'Investigator RoleCode_1',
    'EndDate_1':'Investigator EndDate_1',
    'FirstName_2':'Investigator FirstName_2',
    'LastName_2':'Investigator LastName_2',
    'EmailAddress_2':'Investigator EmailAddress_2',
    'StartDate_2':'Investigator StartDate_2',
    'RoleCode_2':'Investigator RoleCode_2',
    'EndDate_2':'Investigator EndDate_2',
    'Name': 'Institution Name',
    'CityName': 'Institution CityName',
    'ZipCode': 'Institution ZipCode',
    'PhoneNumber': 'Institution PhoneNumber',
    'StreetAddress': 'Institution StreetAddress',
    'CountryName': 'Institution CountryName',
    'StateName': 'Institution StatemName',
    'StateCode': 'Institution StateCode',
    'FirstName_3':'Investigator FirstName_3',
    'LastName_3':'Investigator LastName_3',
    'EmailAddress_3':'Investigator EmailAddress_3',
    'StartDate_3':'Investigator StartDate_3',
    'RoleCode_3':'Investigator RoleCode_3',
    'EndDate_3':'Investigator EndDate_3',
    'FirstName_4':'Investigator FirstName_4',
    'LastName_4':'Investigator LastName_4',
    'EmailAddress_4':'Investigator EmailAddress_4',
    'StartDate_4':'Investigator StartDate_4',
    'RoleCode_4':'Investigator RoleCode_4',
    'EndDate_4':'Investigator EndDate_4',
    'FirstName_5':'Investigator FirstName_5',
    'LastName_5':'Investigator LastName_5',
    'EmailAddress_5':'Investigator EmailAddress_5',
    'StartDate_5':'Investigator StartDate_5',
    'RoleCode_5':'Investigator RoleCode_5',
    'EndDate_5':'Investigator EndDate_5',
    'FirstName_6':'Investigator FirstName_6',
    'LastName_6':'Investigator LastName_6',
    'EmailAddress_6':'Investigator EmailAddress_6',
    'StartDate_6':'Investigator StartDate_6',
    'RoleCode_6':'Investigator RoleCode_6',
    'EndDate_6':'Investigator EndDate_6',
    'FirstName_7':'Investigator FirstName_7',
    'LastName_7':'Investigator LastName_7',
    'EmailAddress_7':'Investigator EmailAddress_7',
    'StartDate_7':'Investigator StartDate_7',
    'RoleCode_7':'Investigator RoleCode_7',
    'EndDate_7':'Investigator EndDate_7',
    'FirstName_8':'Investigator FirstName_8',
    'LastName_8':'Investigator LastName_8',
    'EmailAddress_8':'Investigator EmailAddress_8',
    'StartDate_8':'Investigator StartDate_8',
    'RoleCode_8':'Investigator RoleCode_8',
    'EndDate_8':'Investigator EndDate_8',
    'FirstName_9':'Investigator FirstName_9',
    'LastName_9':'Investigator LastName_9',
    'EmailAddress_9':'Investigator EmailAddress_9',
    'StartDate_9':'Investigator StartDate_9',
    'RoleCode_9':'Investigator RoleCode_9',
    'EndDate_9':'Investigator EndDate_9',
    'FirstName_10':'Investigator FirstName_10',
    'LastName_10':'Investigator LastName_10',
    'EmailAddress_10':'Investigator EmailAddress_10',
    'StartDate_10':'Investigator StartDate_10',
    'RoleCode_10':'Investigator RoleCode_10',
    'EndDate_10':'Investigator EndDate_10',
    'FirstName_11':'Investigator FirstName_11',
    'LastName_11':'Investigator LastName_11',
    'EmailAddress_11':'Investigator EmailAddress_11',
    'StartDate_11':'Investigator StartDate_11',
    'RoleCode_11':'Investigator RoleCode_11',
    'EndDate_11':'Investigator EndDate_11',
}

# %%
    'FirstName_11':'Investigator FirstName_11',
    'LastName_11':'Investigator LastName_11',
    'EmailAddress_11':'Investigator EmailAddress_11',
    'StartDate_11':'Investigator StartDate_11',
    'RoleCode_11':'Investigator RoleCode_11',
    'EndDate_11':'Investigator EndDate_11',
# Out:
#   File "<ipython-input-181-da0b261b94f7>", line 1
#     'FirstName_11':'Investigator FirstName_11',
#                                               ^
# SyntaxError: invalid syntax

# %%
final= df16.rename(col_name_mapping,axis=1)
final.head(10)
# Out:
#    Unnamed: 0                                         AwardTitle  \
# 0           0  Social, Behavioral, and Academic Linkages thro...
# 1           0  Student Travel to the Cornell, Maryland, Max P...
# 2           0  SBIR Phase I:  Droplet Transport Technology fo...
# 3           0  2019 Coastal Ocean Dynamics Gordon Research Co...
# 4           0  The 10th USA-China Joint Chemical Engineering ...
# 5           0  Collaborative Research: CEDAR: Characterizatio...
# 6           0  NSF Postdoctoral Fellowship in Biology FY 2019...
# 7           0  Collaborative Research: TESPRESSO: Tectonic En...
# 8           0    High Order Methods for Kinetic Transport Models
# 9           0  Collaborative Research: Mechanisms of Multicel...
#
#   AwardEffectiveDate AwardExpirationDate  AwardTotalIntnAmount  AwardAmount  \
# 0         02/01/2018          06/30/2020              216805.0       216805
# 1         04/15/2019          03/31/2020               49979.0        49979
# ...

# %%
for columns in df16.columns:
    print(columns)
# Out:
# Unnamed: 0
# AwardTitle
# AwardEffectiveDate
# AwardExpirationDate
# AwardTotalIntnAmount
# AwardAmount
# AwardInstrument
# Value
# Organization
# Code
# Directorate
# Abbreviation
# LongName
# Division
# Abbreviation_1
# LongName_1
# ProgramOfficer
# SignBlockName
# AbstractNarration
# MinAmdLetterDate
# MaxAmdLetterDate
# ARRAAmount
# AwardID
# Investigator
# FirstName
# LastName
# EmailAddress
# StartDate
# EndDate
# RoleCode
# Institution
# Name
# CityName
# ZipCode
# PhoneNumber
# StreetAddress
# CountryName
# StateName
# StateCode
# ProgramElement
# Code_1
# Text
# ProgramReference
# Code_2
# Text_1
# ProgramReference_1
# Code_3
# Text_2
# Investigator_1
# FirstName_1
# LastName_1
# EmailAddress_1
# StartDate_1
# EndDate_1
# RoleCode_1
# ProgramElement_1
# Code_4
# Text_3
# Investigator_2
# FirstName_2
# LastName_2
# EmailAddress_2
# StartDate_2
# EndDate_2
# RoleCode_2
# ProgramReference_2
# Code_5
# Text_4
# ProgramReference_3
# Investigator_3
# FirstName_3
# LastName_3
# ...

# %%
final_export = final[['AwardTitle',
 'AwardEffectiveDate',
 'AwardExpirationDate',
 'AwardAmount',
 #'AwardInstrument',
 'AwardInstrument Value',
 'Directorate Code',
 'Organization Directorate LongName',
 'Organization Division LongName',
 'ProgramOfficer SignBlockName',
 'AbstractNarration',
 'MinAmdLetterDate',
 'MaxAmdLetterDate',
 'ARRAAmount',
 'AwardID',
 'Investigator FirstName',
 'Investigator LastName',
 'Investigator EmailAddress',
 'Investigator StartDate',
 'Investigator EndDate',
 'Investigator RoleCode',
 'Investigator FirstName_1',
 'Investigator LastName_1',
 'Investigator EmailAddress_1',
 'Investigator StartDate_1',
 'Investigator EndDate_1',
 'Investigator RoleCode_1',
 'Investigator FirstName_2',
 'Investigator LastName_2',
 'Investigator EmailAddress_2',
 'Investigator StartDate_2',
 'Investigator EndDate_2',
 'Investigator RoleCode_2',
 'Institution Name',
 'Institution CityName',
 'Institution ZipCode',
 'Institution PhoneNumber',
 'Institution StreetAddress',
 'Institution CountryName',
 'Institution StatemName',
 'Institution StateCode',
 'Investigator FirstName_3',
 'Investigator LastName_3',
 'Investigator EmailAddress_3',
 'Investigator StartDate_3',
 'Investigator EndDate_3',
 'Investigator RoleCode_3',
 'Investigator FirstName_4',
 'Investigator LastName_4',
 'Investigator EmailAddress_4',
 'Investigator StartDate_4',
 'Investigator EndDate_4',
 'Investigator RoleCode_4',
 'AwardTotalIntnAmount',
 'Abbreviation',
 'Abbreviation_1',
 'Investigator FirstName_5',
 'Investigator LastName_5',
 'Investigator EmailAddress_5',
 'Investigator StartDate_5',
 'Investigator EndDate_5',
 'Investigator RoleCode_5']]

final_export
# Out:
#                                              AwardTitle AwardEffectiveDate  \
# 0     Social, Behavioral, and Academic Linkages thro...         02/01/2018
# 1     Student Travel to the Cornell, Maryland, Max P...         04/15/2019
# 2     SBIR Phase I:  Droplet Transport Technology fo...         06/01/2019
# 3     2019 Coastal Ocean Dynamics Gordon Research Co...         04/15/2019
# 4     The 10th USA-China Joint Chemical Engineering ...         11/01/2019
# 5     Collaborative Research: CEDAR: Characterizatio...         09/01/2018
# 6     NSF Postdoctoral Fellowship in Biology FY 2019...         07/01/2019
# 7     Collaborative Research: TESPRESSO: Tectonic En...         06/15/2019
# 8       High Order Methods for Kinetic Transport Models         08/15/2019
# 9     Collaborative Research: Mechanisms of Multicel...         07/01/2019
# 10    Thermodynamics of Tropical Cyclone Overland Ma...         06/01/2019
# ...

# %%
'''
 'Investigator FirstName_10',
 'Investigator LastName_10',
 'Investigator EmailAddress_10',
 'Investigator StartDate_10',
 'Investigator EndDate_10',
 'Investigator RoleCode_10'
 'Investigator FirstName_11',
 'Investigator LastName_11',
 'Investigator EmailAddress_11',
 'Investigator StartDate_11',
 'Investigator EndDate_11',
 'Investigator RoleCode_11'
'''
# Out:
# "\n 'Investigator FirstName_10',\n 'Investigator LastName_10',\n 'Investigator EmailAddress_10',\n 'Investigator StartDate_10',\n 'Investigator EndDate_10',\n 'Investigator RoleCode_10'\n 'Investigator FirstName_11',\n 'Investigator LastName_11',\n 'Investigator EmailAddress_11',\n 'Investigator StartDate_11',\n 'Investigator EndDate_11',\n 'Investigator RoleCode_11'\n"

# %%
final_export.to_csv('2019_nsf_final.csv')
